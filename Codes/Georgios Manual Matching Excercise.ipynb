# %%
import pandas as pd
import numpy as np

df=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Georg Manual Match.xlsx')
aud=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Audits.xlsx')
comm=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Commercial.xlsx')

# %%
aud.head(2)
# Out:
#   Supplier Code              Supplier Name Site Code                Site Name  \
# 0         A6900  HB Gold Standard Supplier   5010692  HB Gold Standard Site 1
# 1         A6900  HB Gold Standard Supplier   5010692  HB Gold Standard Site 1
#
#                                     Audit/Visit Name Latest Audit Date  \
# 0  Audit: Training Module Maintenance - only to b...        2017-11-08
# 1  Audit: Training Module Approval - only to be u...        2017-11-08
#
#   Latest Audit Score Score   Due Date  From Date  ...  \
# 0                NaN  Blue 2017-01-09 2017-01-08  ...
# 1                NaN   NaN 2017-04-27 2017-04-27  ...
#
#   Audits and Visits Status  Site Status list=Business Units  \
# 0        Awaiting Sign-Off       Active      United Kingdom
# 1              In Progress       Active      United Kingdom
#
#                   Path Lead Technical Manager         Country  \
# 0  TRAINING / Training         UK Helen Boley  United Kingdom
# ...

# %%
aud[aud['Supplier Code']=='16965']
df['Supplier_Number.1']=df['Supplier_Number.1'].astype(str)
df[df['Supplier_Number.1']=='16965']
# Out:
#          DATA                Supplier_Name  Supplier_Number      Junior_Buyer  \
# 0  Commercial  ENOTRIA WINECELLARS LTD (AU            62757  AUSTRALIA     O.
#
#              Parent_Supplier_Name DATA.1 Supplier_Name.1 Supplier_Number.1  \
# 0  ENOTRIA WINECELLARS LTD.(ITAL)    TQC   Enotria & Coe             16965
#
#      Junior_Buyer.1
# 0  AUSTRALIA     O.

# %%
df.head(2)
df_with_Sites=df.merge(aud[['Supplier Code','Supplier Name','Site Code','Site Name']],how='left',left_on=['Supplier_Number.1'],right_on=['Supplier Code'])
df_with_Sites.head(2)
# Out:
#          DATA                Supplier_Name  Supplier_Number      Junior_Buyer  \
# 0  Commercial  ENOTRIA WINECELLARS LTD (AU            62757  AUSTRALIA     O.
# 1  Commercial  ENOTRIA WINECELLARS LTD (AU            62757  AUSTRALIA     O.
#
#              Parent_Supplier_Name DATA.1 Supplier_Name.1 Supplier_Number.1  \
# 0  ENOTRIA WINECELLARS LTD.(ITAL)    TQC   Enotria & Coe             16965
# 1  ENOTRIA WINECELLARS LTD.(ITAL)    TQC   Enotria & Coe             16965
#
#      Junior_Buyer.1 Supplier Code  Supplier Name Site Code           Site Name
# 0  AUSTRALIA     O.         16965  Enotria & Coe    210817  d'Arenberg Enotria
# 1  AUSTRALIA     O.         16965  Enotria & Coe    210817  d'Arenberg Enotria

# %%
comm_match=comm.merge(df_with_Sites,how='inner',left_on=['Supplier_Number','Junior_Buyer'],right_on=['Supplier_Number','Junior_Buyer'])
comm_match.head(2)
# Out:
#    Parent_Supplier       Parent_Supplier_name  Supplier_Number  \
# 0              741  ROBERT WISEMAN & SONS LTD            68000
# 1              741  ROBERT WISEMAN & SONS LTD            68000
#
#                  Supplier_Name_x Commercial_Director Commercial_Area  \
# 0  MULLER UK & IRELAND GROUP LLP    FRES          H.           Fresh
# 1  MULLER UK & IRELAND GROUP LLP    FRES          H.           Fresh
#
#   Category_Director   Category_Area Buying_Controller  \
# 0  BAKERY&DAIR   Y.  Bakery & Dairy  CORE DAIRY&AL T.
# 1  BAKERY&DAIR   Y.  Bakery & Dairy  CORE DAIRY&AL T.
#
#                     Buyer_Area  ...                Supplier_Name_y  \
# 0  Dairy Alternatives & Drinks  ...  MULLER UK & IRELAND GROUP LLP
# 1  Dairy Alternatives & Drinks  ...  MULLER UK & IRELAND GROUP LLP
#
#         Parent_Supplier_Name DATA.1            Supplier_Name.1  \
# 0  ROBERT WISEMAN & SONS LTD    TQC  Müller Milk & Ingredients
# ...

# %%
comm_match.to_excel('Georgios_manual_match.xlsx')
