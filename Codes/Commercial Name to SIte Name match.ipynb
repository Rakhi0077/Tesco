# %%
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process 
import pandas as pd

def checker(wrong_options,correct_options):

    names_array=[]
    ratio_array=[]    
    for wrong_option in wrong_options:
        if wrong_option in correct_options:
            names_array.append(wrong_option)
            ratio_array.append('100')
            
           
        else:   
            x=process.extractOne(wrong_option,correct_options,scorer=fuzz.token_set_ratio)
            names_array.append(x[0])
            ratio_array.append(x[1])
    return names_array,ratio_array

df_Original_List=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\TFMS Analysis Template Check %.xlsx',sheet_name='Commercial Data')

df_To_beMatched=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\TFMS Analysis Template Check %.xlsx',sheet_name='TQC Data')

# %%
df_Original_List.head(2)
# Out:
#                   lookup      Origin  Supplier_Number          Supplier_Name  \
# 0  65450WASHIN        G.  Commercial            65450                    OTL
# 1  63057KOSHE         R.  Commercial            63057  GOLDEN ACRE FOODS LTD
#
#   Commercial_Director Commercial_Area Category_Director  \
# 0    PACKAGE       D.        Packaged  HB&WELLNES    S.
# 1    PACKAGE       D.        Packaged  GROCER        Y.
#
#                Category_Area Buying_Controller                  Product_Area  \
# 0  Health, Beauty & Wellness  TOILETRIE     S.                    Toiletries
# 1                    Grocery  INGREDS&GLOBA L.  Ingredients & Global Grocery
#
#    ... Parent_Supplier_Number_TFMS         Parent_Supplier_Name OBL Count  \
# 0  ...                        4723                          OTL         0
# 1  ...                        6404  GOLDEN ACRE DAIRY FOODS LTD         0
#
#   Count Supplier Name from TQC Supplier Code from TQC  \
# 0   216                    NaN                    NaN
# 1  3617                    NaN                    NaN
#
#    Supplier Number from TQC    Match?  COGS  COGS >0
# 0                       NaN  no match   NaN    False
# 1                       NaN  no match   NaN    False
#
# [2 rows x 26 columns]

# %%
df_To_beMatched.head(2)
# Out:
#   lookup Origin Supplier_Code              Supplier_Name Site_Code  \
# 0    NaN    TQC         A6900  HB Gold Standard Supplier   5010692
# 1    NaN    TQC         A6900  HB Gold Standard Supplier   5010692
#
#                  Site_Name                                              Audit  \
# 0  HB Gold Standard Site 1  Audit: Training Module Maintenance - only to b...
# 1  HB Gold Standard Site 1  Audit: Training Module Approval - only to be u...
#
#   Last_Audit_Date Last_Audit_Score Score  ... Empty Column 1 Empty Column 2  \
# 0      2017-11-08              NaN  Blue  ...            NaN            NaN
# 1      2017-11-08              NaN   NaN  ...            NaN            NaN
#
#   Empty Column 3  Empty Column 4 Empty Column 5 Empty Column 6 Empty Column 7  \
# 0            NaN             NaN            NaN            NaN            NaN
# 1            NaN             NaN            NaN            NaN            NaN
#
#   Empty Column 8 Empty Column 9 Empty Column 10
# 0            NaN            NaN             NaN
# 1            NaN            NaN             NaN
#
# [2 rows x 43 columns]

# %%
df_Original_List['Supplier_Name_3']=df_Original_List['Supplier_Name'].str.upper()
df_To_beMatched['Site_Name_3']=df_To_beMatched['Site_Name'].str.upper()


df_Original_List['Supplier_Name_3']=df_Original_List['Supplier_Name_3'].str.replace('LTD','').str.replace('LIMITED','')
df_To_beMatched['Site_Name_3']=df_To_beMatched['Site_Name_3'].str.replace('LTD','').str.replace('LIMITED','')

# %%
# audits_matched=pd.read_excel(r'C:\Users\IN22912959\Audits_Matched.xlsx')

# %%
# not_matched=df_To_beMatched.merge(audits_matched[['Supplier Code','Junior_Buyer','Fuzzy_Ratio']].drop_duplicates(),how='left',left_on=['Supplier Code','Junior_Buyer'],right_on=['Supplier Code','Junior_Buyer'])
# not_matched.head(2)

# %%
not_matched=df_Original_List[df_Original_List['Supplier Name from TQC'].isnull()]
not_matched.head(2)
# Out:
#                   lookup      Origin  Supplier_Number          Supplier_Name  \
# 0  65450WASHIN        G.  Commercial            65450                    OTL
# 1  63057KOSHE         R.  Commercial            63057  GOLDEN ACRE FOODS LTD
#
#   Commercial_Director Commercial_Area Category_Director  \
# 0    PACKAGE       D.        Packaged  HB&WELLNES    S.
# 1    PACKAGE       D.        Packaged  GROCER        Y.
#
#                Category_Area Buying_Controller                  Product_Area  \
# 0  Health, Beauty & Wellness  TOILETRIE     S.                    Toiletries
# 1                    Grocery  INGREDS&GLOBA L.  Ingredients & Global Grocery
#
#    ...         Parent_Supplier_Name OBL Count Count Supplier Name from TQC  \
# 0  ...                          OTL         0   216                    NaN
# 1  ...  GOLDEN ACRE DAIRY FOODS LTD         0  3617                    NaN
#
#   Supplier Code from TQC Supplier Number from TQC    Match? COGS  COGS >0  \
# 0                    NaN                      NaN  no match  NaN    False
# 1                    NaN                      NaN  no match  NaN    False
#
#       Supplier_Name_3
# 0                 OTL
# 1  GOLDEN ACRE FOODS
#
# [2 rows x 27 columns]

# %%
# df_To_beMatched=not_matched
df_To_beMatched.head(2)
df_To_beMatched[df_To_beMatched['Site_Name']=='Pork Farms Caspian - Poole']
# Out:
#                       lookup Origin Supplier_Code    Supplier_Name Site_Code  \
# 2644   48267CHILLED PIE   S.    TQC         29244  Kerry Foods Ltd      2409
# 2645   54138HOT PIE       S.    TQC         29244  Kerry Foods Ltd      2409
# 2646   67866MFP PIE       S.    TQC         29244  Kerry Foods Ltd      2409
# 2647   54138FRONT OF STOR E.    TQC         29244  Kerry Foods Ltd      2409
# 2648   61398FRONT OF STOR E.    TQC         29244  Kerry Foods Ltd      2409
# 2649   11575CHILLED SNACK S.    TQC         29244  Kerry Foods Ltd      2409
# 2650   67866CHILLED SNACK S.    TQC         29244  Kerry Foods Ltd      2409
# 2651   67866EASY ENTRTAIN G.    TQC         29244  Kerry Foods Ltd      2409
# 2669   48267CHILLED PIE   S.    TQC         29244  Kerry Foods Ltd      2409
# 2670   54138HOT PIE       S.    TQC         29244  Kerry Foods Ltd      2409
# 2671   67866MFP PIE       S.    TQC         29244  Kerry Foods Ltd      2409
# 2672   54138FRONT OF STOR E.    TQC         29244  Kerry Foods Ltd      2409
# 2673   61398FRONT OF STOR E.    TQC         29244  Kerry Foods Ltd      2409
# 2674   11575CHILLED SNACK S.    TQC         29244  Kerry Foods Ltd      2409
# 2675   67866CHILLED SNACK S.    TQC         29244  Kerry Foods Ltd      2409
# 2676   67866EASY ENTRTAIN G.    TQC         29244  Kerry Foods Ltd      2409
# 3824   48267CHILLED PIE   S.    TQC         29244  Kerry Foods Ltd      2409
# 3825   54138HOT PIE       S.    TQC         29244  Kerry Foods Ltd      2409
# 3826   67866MFP PIE       S.    TQC         29244  Kerry Foods Ltd      2409
# 3827   54138FRONT OF STOR E.    TQC         29244  Kerry Foods Ltd      2409
# 3828   61398FRONT OF STOR E.    TQC         29244  Kerry Foods Ltd      2409
# 3829   11575CHILLED SNACK S.    TQC         29244  Kerry Foods Ltd      2409
# 3830   67866CHILLED SNACK S.    TQC         29244  Kerry Foods Ltd      2409
# 3831   67866EASY ENTRTAIN G.    TQC         29244  Kerry Foods Ltd      2409
# 7699   48267CHILLED PIE   S.    TQC         29244  Kerry Foods Ltd      2409
# 7700   54138HOT PIE       S.    TQC         29244  Kerry Foods Ltd      2409
# 7701   67866MFP PIE       S.    TQC         29244  Kerry Foods Ltd      2409
# 7702   54138FRONT OF STOR E.    TQC         29244  Kerry Foods Ltd      2409
# 7703   61398FRONT OF STOR E.    TQC         29244  Kerry Foods Ltd      2409
# 7704   11575CHILLED SNACK S.    TQC         29244  Kerry Foods Ltd      2409
# 7705   67866CHILLED SNACK S.    TQC         29244  Kerry Foods Ltd      2409
# 7706   67866EASY ENTRTAIN G.    TQC         29244  Kerry Foods Ltd      2409
# 10042  48267CHILLED PIE   S.    TQC         29244  Kerry Foods Ltd      2409
# 10043  54138HOT PIE       S.    TQC         29244  Kerry Foods Ltd      2409
# 10044  67866MFP PIE       S.    TQC         29244  Kerry Foods Ltd      2409
# 10045  54138FRONT OF STOR E.    TQC         29244  Kerry Foods Ltd      2409
# 10046  61398FRONT OF STOR E.    TQC         29244  Kerry Foods Ltd      2409
# 10047  11575CHILLED SNACK S.    TQC         29244  Kerry Foods Ltd      2409
#
# 3827             NaN            NaN             NaN            NaN
# 3828             NaN            NaN             NaN            NaN
# 3829             NaN            NaN             NaN            NaN
# 3830             NaN            NaN             NaN            NaN
# 3831             NaN            NaN             NaN            NaN
# 7699             NaN            NaN             NaN            NaN
# 7700             NaN            NaN             NaN            NaN
# 7701             NaN            NaN             NaN            NaN
# 7702             NaN            NaN             NaN            NaN
# 7703             NaN            NaN             NaN            NaN
# 7704             NaN            NaN             NaN            NaN
# 7705             NaN            NaN             NaN            NaN
# 7706             NaN            NaN             NaN            NaN
# 10042            NaN            NaN             NaN            NaN
# 10043            NaN            NaN             NaN            NaN
# 10044            NaN            NaN             NaN            NaN
# 10045            NaN            NaN             NaN            NaN
# 10046            NaN            NaN             NaN            NaN
# 10047            NaN            NaN             NaN            NaN
# 10048            NaN            NaN             NaN            NaN
# 10049            NaN            NaN             NaN            NaN
# 13012            NaN            NaN             NaN            NaN
# 13013            NaN            NaN             NaN            NaN
# 13014            NaN            NaN             NaN            NaN
# 13015            NaN            NaN             NaN            NaN
# 13016            NaN            NaN             NaN            NaN
# 13017            NaN            NaN             NaN            NaN
# 13018            NaN            NaN             NaN            NaN
# 13019            NaN            NaN             NaN            NaN
# 14884            NaN            NaN             NaN            NaN
# 14885            NaN            NaN             NaN            NaN
# 14886            NaN            NaN             NaN            NaN
# 14887            NaN            NaN             NaN            NaN
# 14888            NaN            NaN             NaN            NaN
# 14889            NaN            NaN             NaN            NaN
# 14890            NaN            NaN             NaN            NaN
# 14891            NaN            NaN             NaN            NaN
#
#       Empty Column 7 Empty Column 8 Empty Column 9 Empty Column 10  \
# 2644             NaN            NaN            NaN             NaN
# 2645             NaN            NaN            NaN             NaN
# 2646             NaN            NaN            NaN             NaN
# 2647             NaN            NaN            NaN             NaN
# 2648             NaN            NaN            NaN             NaN
# 2649             NaN            NaN            NaN             NaN
# 2650             NaN            NaN            NaN             NaN
# 2651             NaN            NaN            NaN             NaN
# 2669             NaN            NaN            NaN             NaN
# 2670             NaN            NaN            NaN             NaN
# 2671             NaN            NaN            NaN             NaN
# 2672             NaN            NaN            NaN             NaN
# 2673             NaN            NaN            NaN             NaN
# 2674             NaN            NaN            NaN             NaN
# 2675             NaN            NaN            NaN             NaN
# 2676             NaN            NaN            NaN             NaN
# 3824             NaN            NaN            NaN             NaN
# 3825             NaN            NaN            NaN             NaN
# 3826             NaN            NaN            NaN             NaN
# 3827             NaN            NaN            NaN             NaN
# 3828             NaN            NaN            NaN             NaN
# 3829             NaN            NaN            NaN             NaN
# 3830             NaN            NaN            NaN             NaN
# 3831             NaN            NaN            NaN             NaN
# 7699             NaN            NaN            NaN             NaN
# 7700             NaN            NaN            NaN             NaN
# 7701             NaN            NaN            NaN             NaN
# 7702             NaN            NaN            NaN             NaN
# 7703             NaN            NaN            NaN             NaN
# 7704             NaN            NaN            NaN             NaN
# 7705             NaN            NaN            NaN             NaN
# 7706             NaN            NaN            NaN             NaN
# 10042            NaN            NaN            NaN             NaN
# 10043            NaN            NaN            NaN             NaN
# 10044            NaN            NaN            NaN             NaN
# 10045            NaN            NaN            NaN             NaN
# 10046            NaN            NaN            NaN             NaN
# 10047            NaN            NaN            NaN             NaN
# 10048            NaN            NaN            NaN             NaN
# 10049            NaN            NaN            NaN             NaN
# 13012            NaN            NaN            NaN             NaN
# 13013            NaN            NaN            NaN             NaN
# 13014            NaN            NaN            NaN             NaN
# 13015            NaN            NaN            NaN             NaN
# 13016            NaN            NaN            NaN             NaN
# 13017            NaN            NaN            NaN             NaN
# 13018            NaN            NaN            NaN             NaN
# 13019            NaN            NaN            NaN             NaN
# 14884            NaN            NaN            NaN             NaN
# 14885            NaN            NaN            NaN             NaN
# 14886            NaN            NaN            NaN             NaN
# 14887            NaN            NaN            NaN             NaN
# 14888            NaN            NaN            NaN             NaN
# 14889            NaN            NaN            NaN             NaN
# 14890            NaN            NaN            NaN             NaN
# 14891            NaN            NaN            NaN             NaN
#
#                       Site_Name_3
# 2644   PORK FARMS CASPIAN - POOLE
# 2645   PORK FARMS CASPIAN - POOLE
# 2646   PORK FARMS CASPIAN - POOLE
# 2647   PORK FARMS CASPIAN - POOLE
# 2648   PORK FARMS CASPIAN - POOLE
# 2649   PORK FARMS CASPIAN - POOLE
# 2650   PORK FARMS CASPIAN - POOLE
# 2651   PORK FARMS CASPIAN - POOLE
# 2669   PORK FARMS CASPIAN - POOLE
# 2670   PORK FARMS CASPIAN - POOLE
# 2671   PORK FARMS CASPIAN - POOLE
# 2672   PORK FARMS CASPIAN - POOLE
# 2673   PORK FARMS CASPIAN - POOLE
# 2674   PORK FARMS CASPIAN - POOLE
# 2675   PORK FARMS CASPIAN - POOLE
# 2676   PORK FARMS CASPIAN - POOLE
# 3824   PORK FARMS CASPIAN - POOLE
# 3825   PORK FARMS CASPIAN - POOLE
# 3826   PORK FARMS CASPIAN - POOLE
# 3827   PORK FARMS CASPIAN - POOLE
# 3828   PORK FARMS CASPIAN - POOLE
# 3829   PORK FARMS CASPIAN - POOLE
# 3830   PORK FARMS CASPIAN - POOLE
# 3831   PORK FARMS CASPIAN - POOLE
# 7699   PORK FARMS CASPIAN - POOLE
# 7700   PORK FARMS CASPIAN - POOLE
# 7701   PORK FARMS CASPIAN - POOLE
# 7702   PORK FARMS CASPIAN - POOLE
# 7703   PORK FARMS CASPIAN - POOLE
# 7704   PORK FARMS CASPIAN - POOLE
# 7705   PORK FARMS CASPIAN - POOLE
# 7706   PORK FARMS CASPIAN - POOLE
# 10042  PORK FARMS CASPIAN - POOLE
# 10043  PORK FARMS CASPIAN - POOLE
# 10044  PORK FARMS CASPIAN - POOLE
# 10045  PORK FARMS CASPIAN - POOLE
# 10046  PORK FARMS CASPIAN - POOLE
# 10047  PORK FARMS CASPIAN - POOLE
# 10048  PORK FARMS CASPIAN - POOLE
# 10049  PORK FARMS CASPIAN - POOLE
# 13012  PORK FARMS CASPIAN - POOLE
# 13013  PORK FARMS CASPIAN - POOLE
# 13014  PORK FARMS CASPIAN - POOLE
# 13015  PORK FARMS CASPIAN - POOLE
# 13016  PORK FARMS CASPIAN - POOLE
# 13017  PORK FARMS CASPIAN - POOLE
# 13018  PORK FARMS CASPIAN - POOLE
# 13019  PORK FARMS CASPIAN - POOLE
# 14884  PORK FARMS CASPIAN - POOLE
# 14885  PORK FARMS CASPIAN - POOLE
# 14886  PORK FARMS CASPIAN - POOLE
# 14887  PORK FARMS CASPIAN - POOLE
# 14888  PORK FARMS CASPIAN - POOLE
# 14889  PORK FARMS CASPIAN - POOLE
# 14890  PORK FARMS CASPIAN - POOLE
# 14891  PORK FARMS CASPIAN - POOLE
#
# [56 rows x 44 columns]

# %%
jb_comm=df_To_beMatched['Junior_Buyer'].unique()
jb_comm=pd.DataFrame(jb_comm,columns={'Junior_Buyer'})
# jb_comm=jb_comm[jb_comm['Junior_Buyer']=='STONEFRUI     T.']
jb_comm
# Out:
#          Junior_Buyer
# 0    AUSTRALIA     O.
# 1    BERRIE        S.
# 2    SPECIALCHEES  E.
# 3    COUNTERS CHEESE.
# 4    CANNEDMEA     T.
# ..                ...
# 290  PREMIUMHAIRCARE.
# 291  YORKSHIRE     S.
# 292  OUTLET GROCER Y.
# 293  EUROPEA       N.
# 294               NaN
#
# [295 rows x 1 columns]

# %%
cols=['TQC_Supplier_Name','Supplier_Code','Comm_Supplier_Name','junio_buyer','correct_ratio']
# commercial_for_loop=commercial_only_OBL.copy()
df2=pd.DataFrame()

output_list=[]


for i in jb_comm['Junior_Buyer']:
    filter_data_tqc=df_To_beMatched[df_To_beMatched['Junior_Buyer']==i]
    filter_data_comm=not_matched[not_matched['Junior_Buyer']==i]

    if not filter_data_comm.empty:

        str2Match = filter_data_tqc['Site_Name_3'].fillna('######').tolist()
        strSupplier_Code =filter_data_tqc['Supplier_Code'].tolist()
        strOptions =filter_data_comm['Supplier_Name_3'].fillna('######').tolist()
#         strTesco_Brand_Ind =filter_data_tqc['Tesco_Brand_Ind'].fillna('######').tolist()
        
#         name_match,ratio_match=checker(str2Match,strOptions)
        
        for j in range(0,len(str2Match)):
            x=process.extractOne(str2Match[j],strOptions,scorer=fuzz.token_set_ratio)
            while x[1]==100:
                output_list=[str2Match[j],strSupplier_Code[j],x[0],i,x[1]]
                zipped = zip(cols, output_list)
                a_dictionary = dict(zipped)
                df1=pd.DataFrame(a_dictionary,columns=cols,index=[j])
                df2=df2.append(df1)
                #drop row which has the matched supplier name and junor buyer
                strOptions.remove(x[0])
                x=process.extractOne(str2Match[j],strOptions,scorer=fuzz.token_set_ratio)
            strOptions =filter_data_comm['Supplier_Name_3'].fillna('######').tolist()
#                 output_list=[str2Match[j],strSupplier_Code[j],x[0],i,x[1],strTesco_Brand_Ind[j]]
                
#                 filter_data_comm.drop(filter_data_comm[(filter_data_comm['Supplier_Name_3'] ==x[0])&(filter_data_comm['Junior_Buyer'] ==i)].index, inplace = True) 
                
            output_list=[str2Match[j],strSupplier_Code[j],x[0],i,x[1]]
            zipped = zip(cols, output_list)
            a_dictionary = dict(zipped)
            df1=pd.DataFrame(a_dictionary,columns=cols,index=[j])
            df2=df2.append(df1)

        
        
df2.head(2)
# Out:
#          TQC_Supplier_Name Supplier_Code      Comm_Supplier_Name  \
# 0  HB GOLD STANDARD SITE 1         A6900  DISTELL INTERNATIONAL
# 1  HB GOLD STANDARD SITE 1         A6900  DISTELL INTERNATIONAL
#
#         junio_buyer  correct_ratio
# 0  AUSTRALIA     O.             41
# 1  AUSTRALIA     O.             41

# %%
df3=df2[df2['correct_ratio']>=80].drop_duplicates()
df3
# Out:
#                         TQC_Supplier_Name Supplier_Code  \
# 35    LACTALIS - MCLELLAND CHEESE PACKING         46309
# 68   LACTALIS - CALEDONIAN CHEESE COMPANY         46309
# 4                      FRATELLI POLLI SPA         69121
# 32            SANTA MARIA - MILTON KEYNES         67470
# 18                       CHOCOLAT FREY AG       21673-1
# ..                                    ...           ...
# 7                              INNOPHARMA         60486
# 7                           OP CHOCOLATE          12281
# 2                             YVON MAU SA         35028
# 1      PETS CHOICE T/A BOB MARTIN CARDIFF         14178
# 0   HEIFEI KOBAYASHI DAILY PRODUCTS CO.,          53104
#
#                 Comm_Supplier_Name       junio_buyer  correct_ratio
# 35        LACTALIS MCLELLAND (EURO  COUNTERS CHEESE.             88
# 68          ORKNEY CHEESE COMPANY   COUNTERS CHEESE.             80
# 4               FRATELLI POLLI SPA  PASTASAUCE    S.            100
# 32                 SANTA MARIA UK   MEXICA        N.             88
# 18                CHOCOLAT FREY AG  ED GIFT CHOC  O.            100
# ..                             ...               ...            ...
# 7                   INNOPHARMA SRO  VITAMIN       S.            100
# 7               ICAM CHOCOLATE UK   CHOCOBAR&MULT I.             86
# 2   YVON MAU S.A             (EURO  DESSERT       E.             84
# 1                     PETS CHOICE   CATLITTE      R.            100
# 0                    151 PRODUCTS   MEDICIN       E.             80
#
# [113 rows x 5 columns]

# %%
# df2[df2['TQC_Supplier_Name']=='Pork Farms Caspian - Poole']
# Out:
# Empty DataFrame
# Columns: [TQC_Supplier_Name, Supplier_Code, Comm_Supplier_Name, junio_buyer, correct_ratio]
# Index: []

# %%
comm=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Commercial.xlsx')
comm.head(2)
comm['Supplier_Name_3']=comm['Supplier_Name'].str.upper().str.replace('LTD','').str.replace('LIMITED','')
comm.head(2)
# Out:
#    Parent_Supplier         Parent_Supplier_name  Supplier_Number  \
# 0             4723                          OTL            65450
# 1             6404  GOLDEN ACRE DAIRY FOODS LTD            63057
#
#            Supplier_Name Commercial_Director Commercial_Area  \
# 0                    OTL    PACKAGE       D.        Packaged
# 1  GOLDEN ACRE FOODS LTD    PACKAGE       D.        Packaged
#
#   Category_Director              Category_Area Buying_Controller  \
# 0  HB&WELLNES    S.  Health, Beauty & Wellness  TOILETRIE     S.
# 1  GROCER        Y.                    Grocery  INGREDS&GLOBA L.
#
#                        Buyer_Area             Buyer      Junior_Buyer  \
# 0               Bathing & Washing  BATHING&WASHING.  WASHIN        G.
# 1  European, USA, Caribbean & Kos  EUR USA CAR K O.  KOSHE         R.
#
#   Junior_Area                  Product_Area Status    COGS_TY  OBL_Count  \
# 0     Washing                    Toiletries    Yes  19638.919          0
# 1      Kosher  Ingredients & Global Grocery    Yes  76057.291          0
#
#    BL_Count     Supplier_Name_3
# 0       216                 OTL
# 1      3617  GOLDEN ACRE FOODS

# %%
match=comm.merge(df3,how='inner',right_on=['Comm_Supplier_Name','junio_buyer'],left_on=['Supplier_Name_3','Junior_Buyer'])
match.head(2)
# Out:
#    Parent_Supplier            Parent_Supplier_name  Supplier_Number  \
# 0             2581       ASHBURY CONFECTIONERY LTD            40859
# 1             9648  THE AUTHENTIC FOOD COMPANY LTD            68790
#
#                  Supplier_Name Commercial_Director Commercial_Area  \
# 0  ASHBURY CHOCOLATES(IN ADMIN    PACKAGE       D.        Packaged
# 1    THE AUTHENTIC FOOD CO(EUR    FRES          H.           Fresh
#
#   Category_Director   Category_Area Buying_Controller          Buyer_Area  \
# 0  IMPULS        E.         Impulse  CONFECTIONER  Y.    Chocolate Blocks
# 1  PREPARED FOOD S.  Prepared Foods  FROZE         N.  Frozen Ready meals
#
#    ... Status       COGS_TY OBL_Count BL_Count              Supplier_Name_3  \
# 0  ...     No  0.000000e+00        25        0  ASHBURY CHOCOLATES(IN ADMIN
# 1  ...    Yes  1.629933e+07     26259        0    THE AUTHENTIC FOOD CO(EUR
#
#                        TQC_Supplier_Name  Supplier_Code  \
# 0                        LIR CHOCOLATES           53574
# 1  THE AUTHENTIC FOOD COMPANY , SHARSTON          67482
#
#             Comm_Supplier_Name       junio_buyer correct_ratio
# 0  ASHBURY CHOCOLATES(IN ADMIN  TRADCHRISTMA  S.            83
# 1    THE AUTHENTIC FOOD CO(EUR  FZN READY MEALS.            84
#
# [2 rows x 24 columns]

# %%
aud_sites=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Audits.xlsx')
aud_sites.head(2)
# Out:
#   Supplier Code              Supplier Name Site Code                Site Name  \
# 0         A6900  HB Gold Standard Supplier   5010692  HB Gold Standard Site 1
# 1         A6900  HB Gold Standard Supplier   5010692  HB Gold Standard Site 1
#
#                                     Audit/Visit Name Latest Audit Date  \
# 0  Audit: Training Module Maintenance - only to b...        2017-11-08
# 1  Audit: Training Module Approval - only to be u...        2017-11-08
#
#   Latest Audit Score Score   Due Date  From Date  ... Site Status  \
# 0                NaN  Blue 2017-01-09 2017-01-08  ...      Active
# 1                NaN   NaN 2017-04-27 2017-04-27  ...      Active
#
#    list=Business Units                 Path Lead Technical Manager  \
# 0       United Kingdom  TRAINING / Training         UK Helen Boley
# 1       United Kingdom  TRAINING / Training       ZZ Training User
#
#           Country      Junior_Buyer Buying_Controller Category_Director  \
# 0  United Kingdom  AUSTRALIA     O.  WINE          S.  BW            S.
# 1  United Kingdom  AUSTRALIA     O.  WINE          S.  BW            S.
#
#   Commercial_Director Unnamed: 22
# 0    PACKAGE       D.         NaN
# 1    PACKAGE       D.         NaN
#
# [2 rows x 23 columns]

# %%
aud_sites=aud_sites[['Supplier Code','Supplier Name','Site Code','Site Name','Junior_Buyer']].drop_duplicates()
aud_sites.head(2)
# Out:
#   Supplier Code              Supplier Name Site Code                Site Name  \
# 0         A6900  HB Gold Standard Supplier   5010692  HB Gold Standard Site 1
# 2         67880                 Onubafruit       ON5          Costa de Huelva
#
#        Junior_Buyer
# 0  AUSTRALIA     O.
# 2  BERRIE        S.

# %%
match_2=match.merge(aud_sites,how='inner',left_on=['Supplier_Code','Junior_Buyer'],right_on=['Supplier Code','Junior_Buyer'])

# %%
match_2.to_excel('Comm Name to Site matching.xlsx')
