# %%
import pandas as pd

# %%
file=pd.read_csv(r'Downloads/bank.csv')
file.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fcdfea1a2213> in <module>
# ----> 1 file=pd.read_csv(r'Downloads/bank.csv')
#       2 file.head()
#
# NameError: name 'pd' is not defined

# %%
bank_data=file.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c88488ba0605> in <module>
# ----> 1 bank_data=file.copy()
#
# NameError: name 'file' is not defined

# %%
w = bank_data.select_dtypes(include=[object])
w.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-dafad5301ba7> in <module>
# ----> 1 w = bank_data.select_dtypes(include=[object])
#       2 w.head(3)
#
# NameError: name 'bank_data' is not defined

# %%
from sklearn import preprocessing

# %%
    le = preprocessing.LabelEncoder()


    # 2/3. FIT AND TRANSFORM
    # use df.apply() to apply le.fit_transform to all columns
    w_2 = w.apply(le.fit_transform)
    w_2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-44f27bd38124> in <module>
#       4 # 2/3. FIT AND TRANSFORM
#       5 # use df.apply() to apply le.fit_transform to all columns
# ----> 6 w_2 = w.apply(le.fit_transform)
#       7 w_2.head()
#
# NameError: name 'w' is not defined

# %%
f=w_2.join(bank_data[['age','balance','day','duration','campaign','pdays']])
f.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c6ec660d7420> in <module>
# ----> 1 f=w_2.join(bank_data[['age','balance','day','duration','campaign','pdays']])
#       2 f.head(2)
#
# NameError: name 'w_2' is not defined

# %%
f.corr()
# Out:
#                 job   marital  education   default   housing      loan  \
# job        1.000000  0.078314   0.147046 -0.007066 -0.136965 -0.067092
# marital    0.078314  1.000000   0.125845 -0.014691 -0.036345 -0.062029
# education  0.147046  0.125845   1.000000 -0.010709 -0.109168 -0.073154
# default   -0.007066 -0.014691  -0.010709  1.000000  0.011076  0.076434
# housing   -0.136965 -0.036345  -0.109168  0.011076  1.000000  0.076761
# loan      -0.067092 -0.062029  -0.073154  0.076434  0.076761  1.000000
# contact   -0.087915 -0.060456  -0.132540  0.035709  0.226392  0.006829
# month     -0.076011 -0.004070  -0.055868  0.000950  0.219602  0.025329
# poutcome  -0.004238 -0.039424  -0.040262  0.042357 -0.046370  0.026344
# deposit    0.063395  0.067610   0.095948 -0.040680 -0.203888 -0.110580
# age       -0.031603 -0.442782  -0.126018 -0.011425 -0.168700 -0.031418
# balance    0.028736 -0.002138   0.051728 -0.060954 -0.077092 -0.084589
# ...

# %%
X=f[['job', 'marital', 'education','housing','loan','month','poutcome','age','balance','duration','campaign','pdays']]  # Features
y=f['deposit']  # Labels

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2) # 80% training and 20% test

# %%
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=100)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train)

y_pred=clf.predict(X_test)

# %%
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.8231079265562025
