# %%
import pandas as pd
import numpy as np

# %%
sup_list=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\Analysis\Supplier List (Birds Eye Merge).xlsx',sheet_name='Sheet1')
Tpps=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\Tpp\TPPs.xlsx',sheet_name='Sheet2')
comm=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\Analysis\TFMS analysis Template 12 08 2020.xlsx',sheet_name='Commercial Data')

# %%
Tpps.head(2)
# Out:
#     Known As…   Lead Category       Parent Supplier Name  \
# 0      Muller  Bakery & Dairy  ROBERT WISEMAN & SONS LTD
# 1  Arla Foods  Bakery & Dairy                 ARLA FOODS
#
#    Parent Supplier Number
# 0                     741
# 1                    2593

# %%
sup_list.head(2)
# Out:
#    Supplier_Number          Supplier_Name Commercial_Director Commercial_Area  \
# 0            65450                    OTL    PACKAGE       D.        Packaged
# 1            63057  GOLDEN ACRE FOODS LTD    PACKAGE       D.        Packaged
#
#   Category_Director              Category_Area Buying_Controller  \
# 0  HB&WELLNES    S.  Health, Beauty & Wellness  TOILETRIE     S.
# 1  GROCER        Y.                    Grocery  INGREDS&GLOBA L.
#
#                    Product_Area             Buyer  \
# 0                    Toiletries  BATHING&WASHING.
# 1  Ingredients & Global Grocery  EUR USA CAR K O.
#
#                        Buyer_Area      Junior_Buyer Junior_Area Active_Yes_No  \
# 0               Bathing & Washing  WASHIN        G.     Washing           Yes
# 1  European, USA, Caribbean & Kos  KOSHE         R.      Kosher           Yes
#
#   Geography  Parent_Supplier_Number_TFMS         Parent_Supplier_Name
# ...

# %%
comm.head(2)
# Out:
#                   lookup      Origin  Supplier_Number          Supplier_Name  \
# 0  65450WASHIN        G.  Commercial            65450                    OTL
# 1  63057KOSHE         R.  Commercial            63057  GOLDEN ACRE FOODS LTD
#
#   Commercial_Director Commercial_Area Category_Director  \
# 0    PACKAGE       D.        Packaged  HB&WELLNES    S.
# 1    PACKAGE       D.        Packaged  GROCER        Y.
#
#                Category_Area Buying_Controller                  Product_Area  \
# 0  Health, Beauty & Wellness  TOILETRIE     S.                    Toiletries
# 1                    Grocery  INGREDS&GLOBA L.  Ingredients & Global Grocery
#
#    ... Geography Parent_Supplier_Number_TFMS         Parent_Supplier_Name  \
# 0  ...        UK                        4723                          OTL
# 1  ...        UK                        6404  GOLDEN ACRE DAIRY FOODS LTD
#
#   OBL Count Count Supplier Name from TQC  Supplier Code from TQC  \
# ...

# %%
tppcols=['Lead Category','Parent Supplier Name','Known As…','Parent Supplier Number']
tpp_data=Tpps[tppcols].drop_duplicates()
tpp_data.head(2)
# Out:
#     Lead Category       Parent Supplier Name   Known As…  \
# 0  Bakery & Dairy  ROBERT WISEMAN & SONS LTD      Muller
# 1  Bakery & Dairy                 ARLA FOODS  Arla Foods
#
#    Parent Supplier Number
# 0                     741
# 1                    2593

# %%
comm_2=comm[['Parent_Supplier_Number_TFMS','Parent_Supplier_Name']]
cols=['Parent_Supplier_Number_comm','Parent_Supplier_Name_comm']
comm_2.columns=cols
comm_2.head(2)
# Out:
#    Parent_Supplier_Number_comm    Parent_Supplier_Name_comm
# 0                         4723                          OTL
# 1                         6404  GOLDEN ACRE DAIRY FOODS LTD

# %%
tpp_data_2=tpp_data.merge(comm_2.drop_duplicates(),how='left',right_on=['Parent_Supplier_Number_comm'],left_on=['Parent Supplier Number'])

# %%
tpp_data_2.head(2)
# Out:
#     Lead Category       Parent Supplier Name   Known As…  \
# 0  Bakery & Dairy  ROBERT WISEMAN & SONS LTD      Muller
# 1  Bakery & Dairy                 ARLA FOODS  Arla Foods
#
#    Parent Supplier Number  Parent_Supplier_Number_comm  \
# 0                     741                          741
# 1                    2593                         2593
#
#    Parent_Supplier_Name_comm
# 0  ROBERT WISEMAN & SONS LTD
# 1                 ARLA FOODS

# %%
sup_list[sup_list['Parent_Supplier_Name']=='KATSOURIS FRESH FOOD LTD']
# Out:
#       Supplier_Number                Supplier_Name Commercial_Director  \
# 541             35102     BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 673             35102     BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 782             35102     BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 2011            35102     BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 2313            35102     BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 2565            35102     BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 2760            45338  BAKKAVOR FOODS LTD TA(FF(VF    FRES          H.
# 2993            45338  BAKKAVOR FOODS LTD TA(FF(VF    FRES          H.
# 3376            35102     BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 3760            35102     BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 4002            35102     BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 4043            35102     BAKKAVOR FOODS LTD TA(VF    FRES          H.
# ...

# %%
tpp_data_2[tpp_data_2['Known As…']=='Bakkavor']
# Out:
#      Lead Category Parent Supplier Name Known As…  Parent Supplier Number  \
# 10  Prepared Foods             BAKKAVOR  Bakkavor                   10456
# 37         Produce             BAKKAVOR  Bakkavor                   10456
# 38  Prepared Foods             BAKKAVOR  Bakkavor                    1384
# 40  Prepared Foods             BAKKAVOR  Bakkavor                    1305
# 49             MFP             BAKKAVOR  Bakkavor                   10456
# 50  Bakery & Dairy             BAKKAVOR  Bakkavor                   10456
#
#     Parent_Supplier_Number_comm Parent_Supplier_Name_comm
# 10                        10456                  BAKKAVOR
# 37                        10456                  BAKKAVOR
# 38                         1384  KATSOURIS FRESH FOOD LTD
# 40                         1305          LAURENS HOLDINGS
# 49                        10456                  BAKKAVOR
# 50                        10456                  BAKKAVOR

# %%
joined_data=sup_list.merge(tpp_data_2,how='inner',left_on=['Parent_Supplier_Name'],right_on=['Parent_Supplier_Name_comm'])
joined_data.head(2)
# Out:
#    Supplier_Number            Supplier_Name Commercial_Director  \
# 0            45494  BAKKAVOR SPALDING(FF(VF    FRES          H.
# 1            45494  BAKKAVOR SPALDING(FF(VF    FRES          H.
#
#   Commercial_Area Category_Director   Category_Area Buying_Controller  \
# 0           Fresh  PREPARED FOOD S.  Prepared Foods  CHILLE        D.
# 1           Fresh  PREPARED FOOD S.  Prepared Foods  CHILLE        D.
#
#   Product_Area             Buyer     Buyer_Area  ... Active_Yes_No Geography  \
# 0      Chilled  CHILLED PIZZ  A.  Chilled Pizza  ...           Yes        UK
# 1      Chilled  CHILLED PIZZ  A.  Chilled Pizza  ...           Yes        UK
#
#   Parent_Supplier_Number_TFMS Parent_Supplier_Name   Lead Category  \
# 0                       10456             BAKKAVOR  Prepared Foods
# 1                       10456             BAKKAVOR         Produce
#
#   Parent Supplier Name Known As… Parent Supplier Number  \
# 0             BAKKAVOR  Bakkavor                  10456
# ...

# %%
new=joined_data[joined_data['Known As…'].notnull()]

# %%
new[new['Known As…']=='Bakkavor']
# Out:
#       Supplier_Number             Supplier_Name Commercial_Director  \
# 0               45494   BAKKAVOR SPALDING(FF(VF    FRES          H.
# 1               45494   BAKKAVOR SPALDING(FF(VF    FRES          H.
# 2               45494   BAKKAVOR SPALDING(FF(VF    FRES          H.
# 3               45494   BAKKAVOR SPALDING(FF(VF    FRES          H.
# 4               34773      BAKKAVOR SPALDING(VF    FRES          H.
# ...               ...                       ...                 ...
# 1220            35102  BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 1221            35102  BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 1222            35102  BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 1223            35102  BAKKAVOR FOODS LTD TA(VF    FRES          H.
# 1224            35102  BAKKAVOR FOODS LTD TA(VF    FRES          H.
#
#      Commercial_Area Category_Director   Category_Area Buying_Controller  \
# 0              Fresh  PREPARED FOOD S.  Prepared Foods  CHILLE        D.
# ...

# %%
new.to_excel('Nisar.xlsx')

# %%
new_numbers=new[['Known As…','Parent_Supplier_Number_comm']]

# %%
new_numbers['Parent_Supplier_Number_comm']=new_numbers['Parent_Supplier_Number_comm'].astype(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_numbers.head(2)
# Out:
#     Known As…  Parent_Supplier_Number_comm
# 127  Bakkavor                        10456
# 128  Bakkavor                        10456
