# %%
from fuzzywuzzy import fuzz 
from fuzzywuzzy import process 
import pandas as pd

def checker(wrong_options,correct_options):

    names_array=[]
    ratio_array=[]    
    for wrong_option in wrong_options:
        if wrong_option in correct_options:
            names_array.append(wrong_option)
            ratio_array.append('100')
            
           
        else:   
            x=process.extractOne(wrong_option,correct_options,scorer=fuzz.token_set_ratio)
            names_array.append(x[0])
            ratio_array.append(x[1])
    return names_array,ratio_array

df_To_beMatched=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\TFMS Matching Template 2020 12 11.xlsx',sheet_name='Commercial Data')

df_Original_List=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Audits 12 01.xlsx')

# %%
df_To_beMatched=df_To_beMatched[(df_To_beMatched['OBL Count']>0)&(df_To_beMatched['Supplier Code from TQC'].isnull())&(df_To_beMatched['COGS']>1700)]

# %%
df_Original_List.head(2)
# Out:
#    Site Id Site Code      Site Name (English)         Country Site Type  \
# 0     8734   5010774  HB Gold Standard Site 2  United Kingdom   Primary
# 1     8681   5010692  HB Gold Standard Site 1  United Kingdom   Primary
#
#   Site Status  Supplier Id Supplier Code    Supplier Name (English)  \
# 0      Active         5663         A6900  HB Gold Standard Supplier
# 1      Active         5663         A6900  HB Gold Standard Supplier
#
#   list=Business Units  ... Audits and Visits Status     Score   Due Date  \
# 0      United Kingdom  ...        Awaiting Sign-Off  Approved 2016-09-30
# 1      United Kingdom  ...        Awaiting Sign-Off      Blue 2017-01-09
#
#    From Date    To Date            Name Auditor Latest Audit Date  \
# 0 2017-04-10 2017-04-10  UK Helen Boley     Yes        2017-04-27
# 1 2017-01-08 2017-01-09  UK Helen Boley     Yes        2017-11-08
#
#   Latest Audit Score Audits/Visits
# 0                NaN        Audits
# 1                NaN        Audits
#
# [2 rows x 24 columns]

# %%
df_To_beMatched.head(2)
# Out:
#                    lookup      Origin  Supplier_Number  \
# 54  24775CHOCOBISCUIT  S.  Commercial            24775
# 77  49558CHILLEDJUIC   E.  Commercial            49558
#
#                      Supplier_Name Commercial_Director Commercial_Area  \
# 54  NORTHERNFOODS GROCERY GROUP(VF    PACKAGE       D.        Packaged
# 77    REFRESCO BEVERAGES UK LTD(VF    PACKAGE       D.        Packaged
#
#    Category_Director Category_Area Buying_Controller Product_Area  ...  \
# 54  IMPULS        E.       Impulse  BISCUIT       S.     Biscuits  ...
# 77  IMPULS        E.       Impulse  CHILLEDJUIC   E.  Fruit Juice  ...
#
#         Parent_Supplier_Name OBL Count Count Supplier Name from TQC  \
# 54  2 SISTERS FOOD GROUP LTD         6     9                    NaN
# 77    HANOVER ACCEPTANCE LTD        35     4                    NaN
#
#    Supplier Code from TQC Supplier Number from TQC    Match?        COGS  \
# 54                    NaN                      NaN  no match  10099719.0
# 77                    NaN                      NaN  no match  75356598.0
#
#     COGS >0  Flag
# 54     True   NaN
# 77     True   NaN
#
# [2 rows x 27 columns]

# %%
df_Original_List['Supplier_Name_3']=df_Original_List['Supplier Name (English)'].str.upper()
df_To_beMatched['Supplier_Name_3']=df_To_beMatched['Supplier_Name'].str.upper()


df_Original_List['Supplier_Name_3']=df_Original_List['Supplier_Name_3'].str.replace('LTD','').str.replace('LIMITED','')
df_To_beMatched['Supplier_Name_3']=df_To_beMatched['Supplier_Name_3'].str.replace('LTD','').str.replace('LIMITED','')

# %%
df_Original_List.head(2)
cols=['Supplier Code','Supplier Name (English)','Site Code','Site Name (English)','Supplier_Name_3']
df_Original_List_2=df_Original_List[cols].drop_duplicates()

# %%
df_To_beMatched.head(2)
cols=['Supplier_Number','Supplier_Name','Supplier_Name_3']
df_To_beMatched_2=df_To_beMatched[cols].drop_duplicates()

# %%
# df_Original_List[df_Original_List['Supplier_Name_x']=='2 SISTERS FOOD GROUP LTD']
# Out:
# Empty DataFrame
# Columns: [Parent_Supplier, Parent_Supplier_name, Supplier_Number, Supplier_Name_x, Commercial_Director, Commercial_Area, Category_Director, Category_Area, Buying_Controller, Buyer_Area, Buyer, Junior_Buyer, Junior_Area, Product_Area, Status, COGS_TY, OBL_Count, BL_Count, Supplier_Name_y, Supplier Code, Site Code, Fuzzy_Ratio, Supplier_Name_3]
# Index: []
#
# [0 rows x 23 columns]

# %%
# audits_matched=pd.read_excel(r'C:\Users\IN22912959\Audits_Matched.xlsx')

# %%
# audits_matched.head(2)
# Out:
#    Unnamed: 0 Supplier Code Supplier Name_x Site Code_x      Site Name_x  \
# 0           2         67880      Onubafruit         ON5  Costa de Huelva
# 1           3         67880      Onubafruit         ON5  Costa de Huelva
#
#       Audit/Visit Name Latest Audit Date Latest Audit Score  Score   Due Date  \
# 0  Visit: Pre-approval        2018-04-06              Green  Amber 2017-02-16
# 1  Visit: Pre-approval        2018-04-06              Green  Amber 2017-02-16
#
#    ... Category_Director Commercial_Director  Parent_Supplier  \
# 0  ...  PRODUC        E.    FRES          H.            10068
# 1  ...  PRODUC        E.    FRES          H.            10068
#
#   Parent_Supplier_name Supplier_Number              Supplier_Name  \
# 0        ONUBAFRUIT SL           67880  ONUBAFRUIT,S.COOP.AND.(FF
# 1        ONUBAFRUIT SL           67880  ONUBAFRUIT,S.COOP.AND.(FF
#
#   Supplier Name_y Site Code_y      Site Name_y Fuzzy_Ratio
# 0      Onubafruit         ON5  Costa de Huelva   Easy Join
# 1      Onubafruit         ON6        Cartaya 1   Easy Join
#
# [2 rows x 31 columns]

# %%
# not_matched=df_To_beMatched.merge(audits_matched[['Supplier Code','Junior_Buyer','Fuzzy_Ratio']].drop_duplicates(),how='left',left_on=['Supplier Code','Junior_Buyer'],right_on=['Supplier Code','Junior_Buyer'])
# not_matched.head(2)
# Out:
#   Supplier Code              Supplier Name Site Code                Site Name  \
# 0         A6900  HB Gold Standard Supplier   5010692  HB Gold Standard Site 1
# 1         A6900  HB Gold Standard Supplier   5010692  HB Gold Standard Site 1
#
#                                     Audit/Visit Name Latest Audit Date  \
# 0  Audit: Training Module Maintenance - only to b...        2017-11-08
# 1  Audit: Training Module Approval - only to be u...        2017-11-08
#
#   Latest Audit Score Score   Due Date  From Date  ... list=Business Units  \
# 0                NaN  Blue 2017-01-09 2017-01-08  ...      United Kingdom
# 1                NaN   NaN 2017-04-27 2017-04-27  ...      United Kingdom
#
#                   Path Lead Technical Manager         Country  \
# 0  TRAINING / Training         UK Helen Boley  United Kingdom
# 1  TRAINING / Training       ZZ Training User  United Kingdom
#
#        Junior_Buyer Buying_Controller Category_Director Commercial_Director  \
# 0  AUSTRALIA     O.  WINE          S.  BW            S.    PACKAGE       D.
# 1  AUSTRALIA     O.  WINE          S.  BW            S.    PACKAGE       D.
#
#              Supplier_Name_3 Fuzzy_Ratio
# 0  HB GOLD STANDARD SUPPLIER         NaN
# 1  HB GOLD STANDARD SUPPLIER         NaN
#
# [2 rows x 24 columns]

# %%
# not_matched=not_matched[not_matched['Fuzzy_Ratio'].isnull()]
# not_matched

# df_To_beMatched=df_To_beMatched[df_To_beMatched['Match?']=='no match']
# df_To_beMatched.head(2)
# Out:
#                   lookup      Origin  Supplier_Number          Supplier_Name  \
# 0  65450WASHIN        G.  Commercial            65450                    OTL
# 1  63057KOSHE         R.  Commercial            63057  GOLDEN ACRE FOODS LTD
#
#   Commercial_Director Commercial_Area Category_Director  \
# 0    PACKAGE       D.        Packaged  HB&WELLNES    S.
# 1    PACKAGE       D.        Packaged  GROCER        Y.
#
#                Category_Area Buying_Controller                  Product_Area  \
# 0  Health, Beauty & Wellness  TOILETRIE     S.                    Toiletries
# 1                    Grocery  INGREDS&GLOBA L.  Ingredients & Global Grocery
#
#    ... Supplier Code from TQC Supplier Number from TQC    Match?       COGS  \
# 0  ...                    NaN                      NaN  no match  19638.919
# 1  ...                    NaN                      NaN  no match  76057.291
#
#   COGS >0 Unnamed: 26  Unnamed: 27 Unnamed: 28  Unnamed: 29  \
# 0    True         NaN     1763.314  335585.697  4606682.036
# 1    True         NaN        0.000       0.000        1.000
#
#       Supplier_Name_3
# 0                 OTL
# 1  GOLDEN ACRE FOODS
#
# [2 rows x 31 columns]

# %%
# df_To_beMatched=not_matched

# %%
jb_comm=df_To_beMatched_2['Junior_Buyer'].unique()
jb_comm=pd.DataFrame(jb_comm,columns={'Junior_Buyer'})
# jb_comm=jb_comm[jb_comm['Junior_Buyer']=='STONEFRUI     T.']
jb_comm
# Out:
#          Junior_Buyer
# 0    CHOCOBISCUIT  S.
# 1    CHILLEDJUIC   E.
# 2    WASHIN        G.
# 3    FIRSTAI       D.
# 4    COFFE         E.
# ..                ...
# 136  CNTR POULTR   Y.
# 137  FROZEN FIS    H.
# 138  AMBIENTVE     G.
# 139  TABLESAUCE    S.
# 140  PREPKWHITEFIS H.
#
# [141 rows x 1 columns]

# %%
# cols=['TQC_Supplier_Name','Supplier_Code','Comm_Supplier_Name','junio_buyer','correct_ratio']
# # commercial_for_loop=commercial_only_OBL.copy()
# df2=pd.DataFrame()

# output_list=[]


# for i in jb_comm['Junior_Buyer']:
#     filter_data_tqc=df_To_beMatched[df_To_beMatched['Junior_Buyer']==i]
#     filter_data_comm=df_Original_List[df_Original_List['Junior_Buyer']==i]

#     if not filter_data_comm.empty:

#         str2Match = filter_data_tqc['Supplier_Name_3'].fillna('######').tolist()
#         strSupplier_Code =filter_data_tqc['Supplier Code'].tolist()
#         strOptions =filter_data_comm['Supplier_Name_3'].fillna('######').tolist()
# #         strTesco_Brand_Ind =filter_data_tqc['Tesco_Brand_Ind'].fillna('######').tolist()
        
# #         name_match,ratio_match=checker(str2Match,strOptions)
        
#         for j in range(0,len(str2Match)):
#             x=process.extractOne(str2Match[j],strOptions,scorer=fuzz.token_set_ratio)
#             while x[1]==100:
#                 output_list=[str2Match[j],strSupplier_Code[j],x[0],i,x[1]]
#                 zipped = zip(cols, output_list)
#                 a_dictionary = dict(zipped)
#                 df1=pd.DataFrame(a_dictionary,columns=cols,index=[j])
#                 df2=df2.append(df1)
#                 #drop row which has the matched supplier name and junor buyer
#                 strOptions.remove(x[0])
#                 x=process.extractOne(str2Match[j],strOptions,scorer=fuzz.token_set_ratio)
#             strOptions =filter_data_comm['Supplier_Name_3'].fillna('######').tolist()
# #                 output_list=[str2Match[j],strSupplier_Code[j],x[0],i,x[1],strTesco_Brand_Ind[j]]
                
# #                 filter_data_comm.drop(filter_data_comm[(filter_data_comm['Supplier_Name_3'] ==x[0])&(filter_data_comm['Junior_Buyer'] ==i)].index, inplace = True) 
                
#             output_list=[str2Match[j],strSupplier_Code[j],x[0],i,x[1]]
#             zipped = zip(cols, output_list)
#             a_dictionary = dict(zipped)
#             df1=pd.DataFrame(a_dictionary,columns=cols,index=[j])
#             df2=df2.append(df1)

        
        
# df2.head(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-399081b7ccc4> in <module>
#      21         for j in range(0,len(str2Match)):
#      22             x=process.extractOne(str2Match[j],strOptions,scorer=fuzz.token_set_ratio)
# ---> 23             while x[1]==100:
#      24                 output_list=[str2Match[j],strSupplier_Code[j],x[0],i,x[1]]
#      25                 zipped = zip(cols, output_list)
#
# TypeError: 'NoneType' object is not subscriptable

# %%
cols=['TQC_Supplier_Name','Supplier_Code','Comm_Supplier_Name','junio_buyer','correct_ratio']
# commercial_for_loop=commercial_only_OBL.copy()
df2=pd.DataFrame()

output_list=[]


str2Match = df_Original_List_2['Supplier_Name_3'].fillna('######').tolist()
strSupplier_Code =df_Original_List['Supplier Code'].tolist()
strOptions =df_To_beMatched_2['Supplier_Name_3'].fillna('######').tolist()
#         strTesco_Brand_Ind =filter_data_tqc['Tesco_Brand_Ind'].fillna('######').tolist()
        
#         name_match,ratio_match=checker(str2Match,strOptions)
        
for j in range(0,len(str2Match)):
    x=process.extractOne(str2Match[j],strOptions,scorer=fuzz.token_set_ratio)
    while x[1]==100:
        output_list=[str2Match[j],strSupplier_Code[j],x[0],j,x[1]]
        zipped = zip(cols, output_list)
        a_dictionary = dict(zipped)
        df1=pd.DataFrame(a_dictionary,columns=cols,index=[j])
        df2=df2.append(df1)
        #drop row which has the matched supplier name and junor buyer
        strOptions.remove(x[0])
        x=process.extractOne(str2Match[j],strOptions,scorer=fuzz.token_set_ratio)
#     strOptions =df_To_beMatched_2['Supplier_Name_3'].fillna('######').tolist()
#                 output_list=[str2Match[j],strSupplier_Code[j],x[0],i,x[1],strTesco_Brand_Ind[j]]

#                 filter_data_comm.drop(filter_data_comm[(filter_data_comm['Supplier_Name_3'] ==x[0])&(filter_data_comm['Junior_Buyer'] ==i)].index, inplace = True) 

    output_list=[str2Match[j],strSupplier_Code[j],x[0],j,x[1]]
    zipped = zip(cols, output_list)
    a_dictionary = dict(zipped)
    df1=pd.DataFrame(a_dictionary,columns=cols,index=[j])
    df2=df2.append(df1)

        
        
df2.head(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-971b7736c71b> in <module>
#       1 # cols=['TQC_Supplier_Name','Supplier_Code','Comm_Supplier_Name','junio_buyer','correct_ratio']
#       2 # commercial_for_loop=commercial_only_OBL.copy()
# ----> 3 df2=pd.DataFrame()
#       4
#       5 output_list=[]
#
# NameError: name 'pd' is not defined

# %%
df2.head(5)
# Out:
#            TQC_Supplier_Name Supplier_Code             Comm_Supplier_Name  \
# 0  HB GOLD STANDARD SUPPLIER         A6900            ROYAL SANDERS (UK)
# 1  HB GOLD STANDARD SUPPLIER         A6900            ROYAL SANDERS (UK)
# 2                 ONUBAFRUIT         A6900                      EURILAIT
# 3        LONG CLAWSON DAIRY          A6900                DAIRY CREST (VF
# 4                   PRINCES          67880  PRINCES FOOD TRADING DIVISION
#
#    junio_buyer  correct_ratio
# 0            0             44
# 1            1             44
# 2            2             44
# 3            3             56
# 4            4            100

# %%
# df2.to_excel('Name to name match.xlsx')

# %%
df3=df2[df2['correct_ratio']>=80].drop_duplicates()
df3.head(10)
# Out:
#             TQC_Supplier_Name Supplier_Code             Comm_Supplier_Name  \
# 4                    PRINCES          67880  PRINCES FOOD TRADING DIVISION
# 4                    PRINCES          67880                       PRINCES
# 10                 WHITWORTHS         16643                 WHITWORTHS (VF
# 13  SEDA OUTSPAN IBERIA S.L.U         16264     SEDA OUTSPAN IBERIA SL(FOB
# 14     REFRESCO BEVERAGES UK          16264      REFRESCO BEVERAGES UK (VF
# 20                 HUMDINGER          44505                  HUMDINGER (VF
# 24           PILGRIM'S PRIDE          54436                PILGRIMS PRIDE
# 25          GRESSINGHAM FOODS         25788              GRESSINGHAM FOODS
# 26           PILGRIM'S PRIDE          39763                PILGRIMS PRIDE
# 31             ORNUA FOODS UK         62209                    CP FOODS UK
#
#     junio_buyer  correct_ratio
# 4             4            100
# 4             4            100
# 10           10            100
# 13           13             86
# 14           14            100
# 20           20            100
# 24           24             97
# 25           25            100
# 26           26             97
# 31           31             84

# %%
df2[df2['Comm_Supplier_Name']=='2 SISTERS FOOD GROUP LTD']
# Out:
# Empty DataFrame
# Columns: [TQC_Supplier_Name, Supplier_Code, Comm_Supplier_Name, junio_buyer, correct_ratio]
# Index: []

# %%
comm=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Commercial.xlsx')

# %%
comm.head(2)
comm['Supplier_Name_3']=comm['Supplier_Name'].str.upper().str.replace('LTD','').str.replace('LIMITED','')
comm.head(2)
# Out:
#    Parent_Supplier         Parent_Supplier_name  Supplier_Number  \
# 0             4723                          OTL            65450
# 1             6404  GOLDEN ACRE DAIRY FOODS LTD            63057
#
#            Supplier_Name Commercial_Director Commercial_Area  \
# 0                    OTL    PACKAGE       D.        Packaged
# 1  GOLDEN ACRE FOODS LTD    PACKAGE       D.        Packaged
#
#   Category_Director              Category_Area Buying_Controller  \
# 0  HB&WELLNES    S.  Health, Beauty & Wellness  TOILETRIE     S.
# 1  GROCER        Y.                    Grocery  INGREDS&GLOBA L.
#
#                        Buyer_Area             Buyer      Junior_Buyer  \
# 0               Bathing & Washing  BATHING&WASHING.  WASHIN        G.
# 1  European, USA, Caribbean & Kos  EUR USA CAR K O.  KOSHE         R.
#
#   Junior_Area                  Product_Area Status    COGS_TY  OBL_Count  \
# 0     Washing                    Toiletries    Yes  19638.919          0
# 1      Kosher  Ingredients & Global Grocery    Yes  76057.291          0
#
#    BL_Count     Supplier_Name_3
# 0       216                 OTL
# 1      3617  GOLDEN ACRE FOODS

# %%
match=df_To_beMatched.merge(df3,how='inner',right_on=['TQC_Supplier_Name'],left_on=['Supplier_Name_3'])
match.head(2)
# Out:
#                   lookup      Origin  Supplier_Number           Supplier_Name  \
# 0  62629REGULAR CAKE  S.  Commercial            62629   BRIGHT BLUE FOODS LTD
# 1  54329CANNEDFIS     H.  Commercial            54329  LDH (LA DORIA) LIMITED
#
#   Commercial_Director Commercial_Area Category_Director   Category_Area  \
# 0    FRES          H.           Fresh  BAKERY&DAIR   Y.  Bakery & Dairy
# 1    PACKAGE       D.        Packaged  GROCER        Y.         Grocery
#
#   Buying_Controller     Product_Area  ...    Match?         COGS COGS >0 Flag  \
# 0  PLANT BAKER   Y.     Plant Bakery  ...  no match   32848520.0    True  NaN
# 1  CLASSIC GROCERY.  Classic Grocery  ...  no match  102852687.0    True  NaN
#
#       Supplier_Name_3   TQC_Supplier_Name  Supplier_Code  Comm_Supplier_Name  \
# 0  BRIGHT BLUE FOODS   BRIGHT BLUE FOODS           59358  BRIGHT BLUE FOODS
# 1     LDH (LA DORIA)      LDH (LA DORIA)           65213     LDH (LA DORIA)
#
#    junio_buyer  correct_ratio
# 0          183            100
# 1           99            100
#
# [2 rows x 33 columns]

# %%
match.to_excel('Name to name matching.xlsx')

# %%
match_2=df_Original_List.merge(df3,how='inner',right_on=['TQC_Supplier_Name'],left_on=['Supplier_Name_3'])
match_2.head(2)
# Out:
#    Site Id Site Code       Site Name (English)         Country Site Type  \
# 0    19825     2338D  Princes Foods Chichester  United Kingdom   Primary
# 1    19825     2338D  Princes Foods Chichester  United Kingdom   Primary
#
#   Site Status  Supplier Id Supplier Code Supplier Name (English)  \
# 0      Active         7793         12315         Princes Limited
# 1      Active         7793         12315         Princes Limited
#
#   list=Business Units  ... Auditor Latest Audit Date  Latest Audit Score  \
# 0      United Kingdom  ...     Yes        2019-08-20               Green
# 1      United Kingdom  ...     Yes        2019-08-20               Green
#
#   Audits/Visits Supplier_Name_3 TQC_Supplier_Name Supplier_Code  \
# 0        Audits        PRINCES           PRINCES          67880
# 1        Audits        PRINCES           PRINCES          67880
#
#               Comm_Supplier_Name junio_buyer correct_ratio
# 0  PRINCES FOOD TRADING DIVISION           4           100
# 1                       PRINCES            4           100
#
# [2 rows x 30 columns]

# %%
aud_sites=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Audits.xlsx')
aud_sites.head(2)
# Out:
#   Supplier Code              Supplier Name Site Code                Site Name  \
# 0         A6900  HB Gold Standard Supplier   5010692  HB Gold Standard Site 1
# 1         A6900  HB Gold Standard Supplier   5010692  HB Gold Standard Site 1
#
#                                     Audit/Visit Name Latest Audit Date  \
# 0  Audit: Training Module Maintenance - only to b...        2017-11-08
# 1  Audit: Training Module Approval - only to be u...        2017-11-08
#
#   Latest Audit Score Score   Due Date  From Date  ... Site Status  \
# 0                NaN  Blue 2017-01-09 2017-01-08  ...      Active
# 1                NaN   NaN 2017-04-27 2017-04-27  ...      Active
#
#    list=Business Units                 Path Lead Technical Manager  \
# 0       United Kingdom  TRAINING / Training         UK Helen Boley
# 1       United Kingdom  TRAINING / Training       ZZ Training User
#
#           Country      Junior_Buyer Buying_Controller Category_Director  \
# 0  United Kingdom  AUSTRALIA     O.  WINE          S.  BW            S.
# 1  United Kingdom  AUSTRALIA     O.  WINE          S.  BW            S.
#
#   Commercial_Director Unnamed: 22
# 0    PACKAGE       D.         NaN
# 1    PACKAGE       D.         NaN
#
# [2 rows x 23 columns]

# %%
aud_sites=aud_sites[['Supplier Code','Supplier Name','Site Code','Site Name','Junior_Buyer']].drop_duplicates()
aud_sites.head(2)
# Out:
#   Supplier Code              Supplier Name Site Code                Site Name  \
# 0         A6900  HB Gold Standard Supplier   5010692  HB Gold Standard Site 1
# 2         67880                 Onubafruit       ON5          Costa de Huelva
#
#        Junior_Buyer
# 0  AUSTRALIA     O.
# 2  BERRIE        S.

# %%
match.head(2)
# Out:
#    Parent_Supplier  Parent_Supplier_name  Supplier_Number   Supplier_Name  \
# 0              199  W.D.IRWIN & SONS LTD            57191  IRWIN'S BAKERY
# 1              199  W.D.IRWIN & SONS LTD            57191  IRWIN'S BAKERY
#
#   Commercial_Director Commercial_Area Category_Director   Category_Area  \
# 0    FRES          H.           Fresh  BAKERY&DAIR   Y.  Bakery & Dairy
# 1    FRES          H.           Fresh  BAKERY&DAIR   Y.  Bakery & Dairy
#
#   Buying_Controller Buyer_Area  ... Status      COGS_TY OBL_Count BL_Count  \
# 0  PLANT BAKER   Y.       Cake  ...    Yes   137653.102         4      716
# 1  PLANT BAKER   Y.       Cake  ...    Yes  2132267.530         0    15965
#
#   Supplier_Name_3  TQC_Supplier_Name  Supplier_Code  Comm_Supplier_Name  \
# 0  IRWIN'S BAKERY      IRWINS BAKERY          51844      IRWIN'S BAKERY
# 1  IRWIN'S BAKERY      IRWINS BAKERY          51844      IRWIN'S BAKERY
#
#         junio_buyer correct_ratio
# 0  SEASONALCAKE  S.            96
# 1  REGULAR CAKE  S.            96
#
# [2 rows x 24 columns]

# %%
match_2=match.merge(aud_sites,how='inner',left_on=['Supplier_Code','Junior_Buyer'],right_on=['Supplier Code','Junior_Buyer'])

# %%
match_2.head(2)
# Out:
#    Parent_Supplier  Parent_Supplier_name  Supplier_Number   Supplier_Name  \
# 0              199  W.D.IRWIN & SONS LTD            57191  IRWIN'S BAKERY
# 1              199  W.D.IRWIN & SONS LTD            57191  IRWIN'S BAKERY
#
#   Commercial_Director Commercial_Area Category_Director   Category_Area  \
# 0    FRES          H.           Fresh  BAKERY&DAIR   Y.  Bakery & Dairy
# 1    FRES          H.           Fresh  BAKERY&DAIR   Y.  Bakery & Dairy
#
#   Buying_Controller Buyer_Area  ... Supplier_Name_3 TQC_Supplier_Name  \
# 0  PLANT BAKER   Y.       Cake  ...  IRWIN'S BAKERY     IRWINS BAKERY
# 1  PLANT BAKER   Y.       Cake  ...  IRWIN'S BAKERY     IRWINS BAKERY
#
#   Supplier_Code Comm_Supplier_Name       junio_buyer  correct_ratio  \
# 0         51844     IRWIN'S BAKERY  SEASONALCAKE  S.             96
# 1         51844     IRWIN'S BAKERY  REGULAR CAKE  S.             96
#
#    Supplier Code  Supplier Name Site Code      Site Name
# 0          51844  Irwins Bakery      3882  Irwins Bakery
# 1          51844  Irwins Bakery      3882  Irwins Bakery
#
# [2 rows x 28 columns]

# %%
match_2.to_excel('Name to name matching_2.xlsx')

# %%
df_To_beMatched[df_To_beMatched['Supplier_Name_3']=='PRINCES FOOD TRADING DIVISION']
# Out:
#                      lookup      Origin  Supplier_Number  \
# 7270  12315CANNEDVE      G.  Commercial            12315
#
#                       Supplier_Name Commercial_Director Commercial_Area  \
# 7270  PRINCES FOOD TRADING DIVISION    PACKAGE       D.        Packaged
#
#      Category_Director Category_Area Buying_Controller     Product_Area  ...  \
# 7270  GROCER        Y.       Grocery  CLASSIC GROCERY.  Classic Grocery  ...
#
#      OBL Count Count Supplier Name from TQC Supplier Code from TQC  \
# 7270        19    24                    NaN                    NaN
#
#      Supplier Number from TQC    Match?        COGS COGS >0  Flag  \
# 7270                      NaN  no match  51914277.0    True   NaN
#
#                     Supplier_Name_3
# 7270  PRINCES FOOD TRADING DIVISION
#
# [1 rows x 28 columns]

# %%
ntn=pd.read_excel(r'C:\Users\IN22912959\Name to name matching_2.xlsx')
ntn.head(2)
# Out:
#    Site Id Site Code       Site Name (English)         Country Site Type  \
# 0    19825     2338D  Princes Foods Chichester  United Kingdom   Primary
# 1    19825     2338D  Princes Foods Chichester  United Kingdom   Primary
#
#   Site Status  Supplier Id Supplier Code Supplier Name (English)  \
# 0      Active         7793         12315         Princes Limited
# 1      Active         7793         12315         Princes Limited
#
#   list=Business Units  ... Auditor Latest Audit Date  Latest Audit Score  \
# 0      United Kingdom  ...     Yes        2019-08-20               Green
# 1      United Kingdom  ...     Yes        2019-08-20               Green
#
#   Audits/Visits Supplier_Name_3 TQC_Supplier_Name Supplier_Code  \
# 0        Audits        PRINCES           PRINCES          12315
# 1        Audits        PRINCES           PRINCES          24242
#
#               Comm_Supplier_Name junio_buyer correct_ratio
# 0  PRINCES FOOD TRADING DIVISION         NaN           100
# 1                       PRINCES          NaN           100
#
# [2 rows x 30 columns]

# %%
match_3=ntn.merge(df_To_beMatched[['Supplier_Number','Supplier_Name','Junior_Buyer']],how='inner',left_on=['Supplier_Code'],right_on=['Supplier_Number'])

# %%
match_3.to_excel('match_3.xlsx')
