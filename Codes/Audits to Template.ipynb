# %%
import pandas as pd
import numpy as np

# %%
Audits=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\TFMS Analysis Template Dec 8.xlsx',sheet_name='TQC Data')
Commercial=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\TFMS Analysis Template Dec 8.xlsx',sheet_name='Commercial Data')
Match=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Matching Task Output_2.xlsx')

# %%
aud=Audits.copy()
comm=Commercial.copy()
match=Match.copy()

# %%
# aud.columns
# aud=aud[aud['Supplier_Number'].isnull()]
# aud.head(2)
comm.head(2)
com=comm[comm['Supplier Code from TQC'].isnull()]

# %%
comm.head(2)
# Out:
#                   lookup      Origin  Supplier_Number          Supplier_Name  \
# 0  65450WASHIN        G.  Commercial            65450                    OTL
# 1  63057KOSHE         R.  Commercial            63057  GOLDEN ACRE FOODS LTD
#
#   Commercial_Director Commercial_Area Category_Director  \
# 0    PACKAGE       D.        Packaged  HB&WELLNES    S.
# 1    PACKAGE       D.        Packaged  GROCER        Y.
#
#                Category_Area Buying_Controller                  Product_Area  \
# 0  Health, Beauty & Wellness  TOILETRIE     S.                    Toiletries
# 1                    Grocery  INGREDS&GLOBA L.  Ingredients & Global Grocery
#
#    ... Supplier Name from TQC Supplier Code from TQC Supplier Number from TQC  \
# 0  ...                    NaN                    NaN                      NaN
# 1  ...                    NaN                    NaN                      NaN
#
#      Match?       COGS COGS >0  Unnamed: 26 Unnamed: 27  Unnamed: 28  \
# ...

# %%
match=match[match['Fuzzy_Ratio']=='Tpp Manual Match']

# %%
match_2=match[['Supplier_Number','Supplier_Name','Category_Director','Commercial_Director','Buying_Controller','Junior_Buyer','Supplier Code','Fuzzy_Ratio']].drop_duplicates()
match_2.head(2)
# Out:
#        Supplier_Number                  Supplier_Name Category_Director  \
# 11859            34758  MULLER UK & IRELAND GROUP LLP  BAKERY&DAIR   Y.
# 11860            34758  MULLER UK & IRELAND GROUP LLP  BAKERY&DAIR   Y.
#
#       Commercial_Director Buying_Controller      Junior_Buyer Supplier Code  \
# 11859    FRES          H.  CORE DAIRY&AL T.  DAIRYALTERNATIV.         44422
# 11860    FRES          H.  CHEESE YOGUT  S.  ADULTYOGURT   S.         44422
#
#             Fuzzy_Ratio
# 11859  Tpp Manual Match
# 11860  Tpp Manual Match

# %%
match[match['Supplier Code']=='29244']
# Out:
# Empty DataFrame
# Columns: [Parent_Supplier, Parent_Supplier_name, Supplier_Number, Supplier_Name, Commercial_Director, Commercial_Area, Category_Director, Category_Area, Buying_Controller, Buyer_Area, Buyer, Junior_Buyer, Junior_Area, Product_Area, Status, COGS_TY, OBL_Count, BL_Count, Supplier Code, Supplier Name, Site Code, Site Name, Fuzzy_Ratio]
# Index: []
#
# [0 rows x 23 columns]

# %%
# aud[['Supplier_Code','Junior_Buyer']][(aud['Supplier_Code']=='29244')].drop_duplicates()

# %%
# cols_order=['Supplier_Code', 'Supplier_Name', 'Site_Code','Site_Name', 'Audit', 'Last_Audit_Date', 'Last_Audit_Score', 'Score','Due_Date', 'From_Date', 'To_Date', 'Audit_Visit_Id','Audit_Visit_Status', 'Site_Status', 'Lead_Technical_Manager','Business_Units', 'Country', 'Path', 'OBL_Count', 'BL_Count','Junior_Buyer', 'Buying_Controller', 'Category_Director','Commercial_Director',]
# aud=aud[cols_order]
# aud.head(2)

# %%
# len(aud[['Supplier_Code','Site_Code']].drop_duplicates())
aud['Supplier_Code']=aud['Supplier_Code'].astype(str)
match_2['Supplier Code']=match_2['Supplier Code'].astype(str)
# match_2.dtypes

# %%
aud_merge=aud.merge(match_2,how='left',left_on=['Supplier_Code'],right_on=['Supplier Code'])
aud_merge
# Out:
#                         lookup Origin Supplier_Code  \
# 0                          NaN    TQC         A6900
# 1                          NaN    TQC         A6900
# 2        34749SPECIALCHEES  E.    TQC         11418
# 3        58879COUNTERS CHEESE.    TQC         11418
# 4        34749COUNTERS CHEESE.    TQC         11418
# ...                        ...    ...           ...
# 1133944                    NaN    NaN           nan
# 1133945                    NaN    NaN           nan
# 1133946                    NaN    NaN           nan
# 1133947                    NaN    NaN           nan
# 1133948                    NaN    NaN           nan
#
#                     Supplier_Name_x Site_Code  \
# 0         HB Gold Standard Supplier   5010692
# 1         HB Gold Standard Supplier   5010692
# 2        Long Clawson Dairy Limited      4968
# 3        Long Clawson Dairy Limited      4968
# 4        Long Clawson Dairy Limited      4968
# ...                             ...       ...
# ...

# %%
len(aud_merge[['Supplier Code','Site Code']].drop_duplicates())
# Out:
# 10

# %%
# matched_audits=aud_merge[aud_merge['Supplier_Number'].notnull()]
# len(matched_audits[['Supplier Code','Site Code_x']].drop_duplicates())

# %%
aud_merge.shape
# Out:
# (127271, 29)

# %%
aud_merge.drop_duplicates().to_excel('Audits_Template.xlsx')
