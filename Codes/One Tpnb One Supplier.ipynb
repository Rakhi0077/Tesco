# %%
import pandas as pd
import numpy as np
aud=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Audits.xlsx')
comm=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\Commercial.xlsx')
match=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\One Tpnb One Supplier.xlsx',sheet_name='Matched Ones')
hie=pd.read_excel(r'C:\Users\IN22912959\OneDrive - Tesco\Documents\Supplier Score Card\New folder\hierarchy.xlsx')

# %%
match.head(2)
# Out:
#   Supplier_Code                          Supplier_Name  Site_Code  \
# 0       1000280  Global Cosmetics (HK) Company Limited   518625.0
# 1       1000280  Global Cosmetics (HK) Company Limited   213521.0
#
#                                            Site_Name      TPNB  \
# 0           Global Cosmetics (China) Company Limited  83321317
# 1  Shen Zhen Tian He Yuan Enterprise Limited (Sit...  86687032
#
#    comm_Supplier_Number             comm_Supplier_Name  \
# 0                 68358  GLOBAL COSMETICS (HK) CO(USD)
# 1                 68358  GLOBAL COSMETICS (HK) CO(USD)
#
#   com_Parent_Supplier_Name
# 0     GLOBAL COSMETICS LTD
# 1     GLOBAL COSMETICS LTD

# %%
comm.head(2)
# Out:
#    Parent_Supplier         Parent_Supplier_name  Supplier_Number  \
# 0             4723                          OTL            65450
# 1             6404  GOLDEN ACRE DAIRY FOODS LTD            63057
#
#            Supplier_Name Commercial_Director Commercial_Area  \
# 0                    OTL    PACKAGE       D.        Packaged
# 1  GOLDEN ACRE FOODS LTD    PACKAGE       D.        Packaged
#
#   Category_Director              Category_Area Buying_Controller  \
# 0  HB&WELLNES    S.  Health, Beauty & Wellness  TOILETRIE     S.
# 1  GROCER        Y.                    Grocery  INGREDS&GLOBA L.
#
#                        Buyer_Area             Buyer      Junior_Buyer  \
# 0               Bathing & Washing  BATHING&WASHING.  WASHIN        G.
# 1  European, USA, Caribbean & Kos  EUR USA CAR K O.  KOSHE         R.
#
#   Junior_Area                  Product_Area Status    COGS_TY  OBL_Count  \
# 0     Washing                    Toiletries    Yes  19638.919          0
# ...

# %%
hie.head(2)
# Out:
#    Base_Product_Number Product_Sub_Group_Code      Junior_Buyer  \
# 0             50000097                  F79AA  FROZEN PIZZ   A.
# 1             50000379                  F34AC  FROZEN MEA    T.
#
#   Buying_Controller Category_Director Commercial_Director           Company
# 0  FROZE         N.  PREPARED FOOD S.    FRES          H.  BRASHER       R.
# 1  FROZE         N.  PREPARED FOOD S.    FRES          H.  BRASHER       R.

# %%
jbs=hie[['Base_Product_Number','Junior_Buyer']].drop_duplicates()
jbs.head(2)
# Out:
#    Base_Product_Number      Junior_Buyer
# 0             50000097  FROZEN PIZZ   A.
# 1             50000379  FROZEN MEA    T.

# %%
match_2=match.merge(jbs,how='left',left_on=['TPNB'],right_on=['Base_Product_Number'])
match_2.head(2)
# Out:
#   Supplier_Code                          Supplier_Name  Site_Code  \
# 0       1000280  Global Cosmetics (HK) Company Limited   518625.0
# 1       1000280  Global Cosmetics (HK) Company Limited   213521.0
#
#                                            Site_Name      TPNB  \
# 0           Global Cosmetics (China) Company Limited  83321317
# 1  Shen Zhen Tian He Yuan Enterprise Limited (Sit...  86687032
#
#    comm_Supplier_Number             comm_Supplier_Name  \
# 0                 68358  GLOBAL COSMETICS (HK) CO(USD)
# 1                 68358  GLOBAL COSMETICS (HK) CO(USD)
#
#   com_Parent_Supplier_Name  Base_Product_Number      Junior_Buyer
# 0     GLOBAL COSMETICS LTD             83321317  GIF           T.
# 1     GLOBAL COSMETICS LTD             86687032  GIF           T.

# %%
final=comm.merge(match_2,how='inner',left_on=['Supplier_Number','Junior_Buyer'],right_on=['comm_Supplier_Number','Junior_Buyer'])
final.head(2)
# Out:
#    Parent_Supplier Parent_Supplier_name  Supplier_Number  \
# 0             5036      FRIESLAND FOODS            62274
# 1             5036      FRIESLAND FOODS            62274
#
#                 Supplier_Name_x Commercial_Director Commercial_Area  \
# 0  FRIESLANDCAMPINANEDERLAND BV    FRES          H.           Fresh
# 1  FRIESLANDCAMPINANEDERLAND BV    FRES          H.           Fresh
#
#   Category_Director   Category_Area Buying_Controller Buyer_Area  ...  \
# 0  BAKERY&DAIR   Y.  Bakery & Dairy  CHEESE YOGUT  S.     Cheese  ...
# 1  BAKERY&DAIR   Y.  Bakery & Dairy  CHEESE YOGUT  S.     Cheese  ...
#
#   BL_Count Supplier_Code   Supplier_Name_y Site_Code  \
# 0        0         62274  FrieslandCampina  105615.0
# 1        0         62274  FrieslandCampina  105615.0
#
#                   Site_Name      TPNB  comm_Supplier_Number  \
# 0  FrieslandCampina Leerdam  60930109                 62274
# 1  FrieslandCampina Leerdam  60930207                 62274
#
# ...

# %%
final.to_excel('one tpnb one supplier matching exercise.xlsx')
